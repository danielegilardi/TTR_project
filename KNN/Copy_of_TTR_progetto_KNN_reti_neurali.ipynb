# %% [markdown]
# <a href="https://colab.research.google.com/github/danielegilardi/TTR_project/blob/main/Copy_of_TTR_progetto_KNN_reti_neurali.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Classificatore: KNN
#
# Features: estratte da resnet 50 (non normalizzate)

# %%
# !wget https://www.dropbox.com/s/l1ybi3k5zmusf9m/features_resnet.zip?dl=0
# !unzip features_resnet.zip?dl=0

# !wget https://www.dropbox.com/s/rhbde9gw8vnk9dm/array_labels.zip?dl=0
# !unzip array_labels.zip?dl=0
# Out:
# --2022-05-09 16:18:55--  https://www.dropbox.com/s/l1ybi3k5zmusf9m/features_resnet.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6022:18::a27d:4212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/l1ybi3k5zmusf9m/features_resnet.zip [following]
# --2022-05-09 16:18:55--  https://www.dropbox.com/s/raw/l1ybi3k5zmusf9m/features_resnet.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc161c2a0b69c10203b24dc0f023.dl.dropboxusercontent.com/cd/0/inline/Bk-xxFXUapL_P6CEBEQISSWun3mwoS5oQHwdcXu_kGVt2SmQiWL-TAOIM0ho0UMfgrku9vKOmv_UT7lORurEbMDUWlZIiWQXrwkkYRdDz_LUNkLrils-bcbHmUn0xt5aFm8QG4yIPOJ0-jwW6HYLb5rzMwhIvz1bJnUpAOIz5jgXTg/file# [following]
# --2022-05-09 16:18:56--  https://uc161c2a0b69c10203b24dc0f023.dl.dropboxusercontent.com/cd/0/inline/Bk-xxFXUapL_P6CEBEQISSWun3mwoS5oQHwdcXu_kGVt2SmQiWL-TAOIM0ho0UMfgrku9vKOmv_UT7lORurEbMDUWlZIiWQXrwkkYRdDz_LUNkLrils-bcbHmUn0xt5aFm8QG4yIPOJ0-jwW6HYLb5rzMwhIvz1bJnUpAOIz5jgXTg/file
# Resolving uc161c2a0b69c10203b24dc0f023.dl.dropboxusercontent.com (uc161c2a0b69c10203b24dc0f023.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6017:15::a27d:20f
# Connecting to uc161c2a0b69c10203b24dc0f023.dl.dropboxusercontent.com (uc161c2a0b69c10203b24dc0f023.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bk8nD3lYL9urxvP07FhkQt1WRscSQZrLjuEdkLSlFLlzM5eC3Z51pcNUWMPv8BQZsvp5PMBKXnT5wSieN9Bk_Z2wOHCd8BYeVwQvlIxDrh4a7OO9X2xnamB3TMcPerTchhfWW5WMZVMSegNhfxU0DhdAaLKvAAccWSRHLA9CjkGVeN56tZ0WWpZK9C7_nejT4eZVZWuyYcFdw8yn1OCBemxCUZUr6mXM7ITPToWUbwg32D4SYtNkgRBWHnEszcHs1NiuTCAgy52TBpzpREGIr-MxAGlMTN9E_moDkDfLc8V9PaQiGRx45z5dig5Cs-_1jg5sWrdKizNAJnbjXUbTdvVknUjWovFeCxmo86nIPGp7tMSbXjRKAaZ5nNGVPF_WP0lEjXI1R5QKYT3rEDfkQ1PHeQt2B8-hU5XyoU2dxIvNtg/file [following]
# --2022-05-09 16:18:56--  https://uc161c2a0b69c10203b24dc0f023.dl.dropboxusercontent.com/cd/0/inline2/Bk8nD3lYL9urxvP07FhkQt1WRscSQZrLjuEdkLSlFLlzM5eC3Z51pcNUWMPv8BQZsvp5PMBKXnT5wSieN9Bk_Z2wOHCd8BYeVwQvlIxDrh4a7OO9X2xnamB3TMcPerTchhfWW5WMZVMSegNhfxU0DhdAaLKvAAccWSRHLA9CjkGVeN56tZ0WWpZK9C7_nejT4eZVZWuyYcFdw8yn1OCBemxCUZUr6mXM7ITPToWUbwg32D4SYtNkgRBWHnEszcHs1NiuTCAgy52TBpzpREGIr-MxAGlMTN9E_moDkDfLc8V9PaQiGRx45z5dig5Cs-_1jg5sWrdKizNAJnbjXUbTdvVknUjWovFeCxmo86nIPGp7tMSbXjRKAaZ5nNGVPF_WP0lEjXI1R5QKYT3rEDfkQ1PHeQt2B8-hU5XyoU2dxIvNtg/file
# Reusing existing connection to uc161c2a0b69c10203b24dc0f023.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 233406633 (223M) [application/zip]
# Saving to: ‘features_resnet.zip?dl=0’
#
# features_resnet.zip 100%[===================>] 222.59M  47.2MB/s    in 4.9s
#
# 2022-05-09 16:19:02 (45.3 MB/s) - ‘features_resnet.zip?dl=0’ saved [233406633/233406633]
#
# Archive:  features_resnet.zip?dl=0
#    creating: features_resnet/
#   inflating: features_resnet/features_test_resnet.npy
#   inflating: features_resnet/features_train_resnet.npy
# --2022-05-09 16:19:09--  https://www.dropbox.com/s/rhbde9gw8vnk9dm/array_labels.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6022:18::a27d:4212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/rhbde9gw8vnk9dm/array_labels.zip [following]
# --2022-05-09 16:19:09--  https://www.dropbox.com/s/raw/rhbde9gw8vnk9dm/array_labels.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc251da4aa573414dcbcaa0ca164.dl.dropboxusercontent.com/cd/0/inline/Bk9vxknrNGmHLYBKFHR_yH1B8Qry7qqNlha8CDeXVjJxVycK6QnGo5XDxWTCdwR9Vm2mI2nokpJjauxe8ZbLMkOpA565Qjv_olXiBr470PNBASQE5Cursx3MaaDNnK2aTho54KH1NA5YzJyKrU6DKXv02clKKL4Bx9Xr439jt4T9Cg/file# [following]
# --2022-05-09 16:19:10--  https://uc251da4aa573414dcbcaa0ca164.dl.dropboxusercontent.com/cd/0/inline/Bk9vxknrNGmHLYBKFHR_yH1B8Qry7qqNlha8CDeXVjJxVycK6QnGo5XDxWTCdwR9Vm2mI2nokpJjauxe8ZbLMkOpA565Qjv_olXiBr470PNBASQE5Cursx3MaaDNnK2aTho54KH1NA5YzJyKrU6DKXv02clKKL4Bx9Xr439jt4T9Cg/file
# Resolving uc251da4aa573414dcbcaa0ca164.dl.dropboxusercontent.com (uc251da4aa573414dcbcaa0ca164.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6017:15::a27d:20f
# Connecting to uc251da4aa573414dcbcaa0ca164.dl.dropboxusercontent.com (uc251da4aa573414dcbcaa0ca164.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bk9MRIlxvUMc2V8zPHKF77Y8N8irxtEyXV_pamBS0tvInABjCrWbMEqmNrIAXnz15AOFUGQPIt05rtHcawRi4kVUSiRx6RdZLm91FEgu3bLPFlZyKvHV9VlFO5hRziuaDhjwSPolRN0KY27CTqUtFUVrANulsdSNMPDV_QMKXOaaLWu1s9ACcROVuyyvLCg7JYRitoLhumVy985CH5poEVtxkihrAkPl1Mol0sk1iMNzcvYYnWk2BInEBXaGErhtGqz8GIBhhbC8DTuvGfiRWkJFq97dfBWx4oImpfp0pkBBzGhDDyPRJVjRmsNhaBUdBoWFzEILEcTQ9al9yUBFBVJuO1Or6aVTdagazYQFIwIDr8XHfjz0iN9b6XNiYCMSnfV-Z9Sv5IUjGb2g4BwFiA78-l2e6Y5psDcTvaBUdVs4eg/file [following]
# --2022-05-09 16:19:10--  https://uc251da4aa573414dcbcaa0ca164.dl.dropboxusercontent.com/cd/0/inline2/Bk9MRIlxvUMc2V8zPHKF77Y8N8irxtEyXV_pamBS0tvInABjCrWbMEqmNrIAXnz15AOFUGQPIt05rtHcawRi4kVUSiRx6RdZLm91FEgu3bLPFlZyKvHV9VlFO5hRziuaDhjwSPolRN0KY27CTqUtFUVrANulsdSNMPDV_QMKXOaaLWu1s9ACcROVuyyvLCg7JYRitoLhumVy985CH5poEVtxkihrAkPl1Mol0sk1iMNzcvYYnWk2BInEBXaGErhtGqz8GIBhhbC8DTuvGfiRWkJFq97dfBWx4oImpfp0pkBBzGhDDyPRJVjRmsNhaBUdBoWFzEILEcTQ9al9yUBFBVJuO1Or6aVTdagazYQFIwIDr8XHfjz0iN9b6XNiYCMSnfV-Z9Sv5IUjGb2g4BwFiA78-l2e6Y5psDcTvaBUdVs4eg/file
# Reusing existing connection to uc251da4aa573414dcbcaa0ca164.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1265 (1.2K) [application/zip]
# Saving to: ‘array_labels.zip?dl=0’
#
# array_labels.zip?dl 100%[===================>]   1.24K  --.-KB/s    in 0s
#
# 2022-05-09 16:19:10 (158 MB/s) - ‘array_labels.zip?dl=0’ saved [1265/1265]
#
# Archive:  array_labels.zip?dl=0
#    creating: array_labels/
#   inflating: array_labels/array_test_labels.npy
#   inflating: array_labels/array_train_labels.npy

# %%
import numpy as np

# 1. Carico in memoria il dataset
x_train = np.load('features_resnet/features_train_resnet.npy')
y_train = np.load('array_labels/array_train_labels.npy')

x_test = np.load('features_resnet/features_test_resnet.npy')
y_test = np.load('array_labels/array_test_labels.npy')

# %%
# Analizzo i dati

# Capisco quanti oggetti e feature ho
nobj = x_train.shape[0]
nfeat = x_train.shape[1]
print(nobj, nfeat)

# Capisco come sono i dati: scatter plot
from matplotlib import pyplot as plt

plt.scatter(x_train[:,0],x_train[:,1], c=y_train)
plt.show()
# Out:
# 31805 2048

# %%
# Inizializzo i parametri

K = 3
fun = 'euclidean'

# Calcolo la distanza fra tutti gli oggetti di train e gli oggetti di test

from scipy.spatial.distance import cdist

D = cdist(x_train,x_test,metric=fun)
 
# Per ogni dato di test (argomento axis=0), ordino le distanze dalla più piccola alla più grande e trovo gli indici di train dei più vicini
# Tengo solo i primi K

neighbors = np.argsort(D, axis=0)

k_neighbors = neighbors[:K, :]

# Controllo le etichette di questi K punti: devo trovare la più frequente:
#     - Ottengo le etichette dei punti vicini
#     - Trovo l'etichetta più frequente, Utilizzo la moda

neighbors_labels = y_train[k_neighbors]


from scipy import stats
prediction = stats.mode(neighbors_labels, axis=0)[0]
print(np.shape(prediction))
print(prediction[:20])


# Calcolo l'accuratezza
accuracy = np.sum(prediction == y_test) / len(y_test)
print('Accuratezza del classificatore: ' + "{0:.2f}".format(accuracy*100) + '%')
# Out:
# (1, 7178)
# [[0 0 0 ... 3 6 3]]
# Accuratezza del classificatore: 39.61%

# %%
length = prediction.shape[1]
print(length)
print(prediction[:20])

predicted = np.reshape(prediction, length)

print(np.shape(predicted))
print(predicted[:20])
# Out:
# 7178
# [[0 0 0 ... 3 6 3]]
# (7178,)
# [0 0 0 0 3 0 0 0 0 0 0 4 0 2 0 3 5 0 4 0]

# %%
# matrice di confusione

cmc = np.zeros((7,7))

for pr,y_te in zip(predicted,y_test):
  cmc[y_te,pr] += 1.0

# %%
# calcolo accuratezza, precision e recall media rispetto alle 7 classi

accuracy = np.sum(cmc.diagonal())/np.sum(cmc)

precision = []
recall = []
for i in range(7):
  precision.append(cmc[i,i]/ np.sum(cmc[:,i]))
  recall.append(cmc[i,i]/ np.sum(cmc[:,i]))

precision = np.asarray(precision)
recall  = np.asarray(recall)

print(np.shape(precision))
print(np.shape(recall))

precision_m = np.mean(precision)
recall_m = np.mean(recall)

print(np.shape(precision_m))
print(np.shape(recall_m))
print(precision_m)
print(recall_m)

print('Accuratezza del classificatore: ' + "{0:.2f}".format(accuracy*100) + '%')
print('Precisione media del classificatore: ' + "{0:.2f}".format(precision_m))
print('Recall media del classificatore: ' + "{0:.2f}".format(recall_m))
# Out:
# (7,)
# (7,)
# ()
# ()
# 0.4284043488469537
# 0.4284043488469537
# Accuratezza del classificatore: 39.61%
# Precisione media del classificatore: 0.43
# Recall media del classificatore: 0.43

# %%
# stampo la matrice di confusione

from matplotlib import pyplot as plt
import seaborn as sns; 


plt.rcParams["figure.figsize"] = (8,6)
sns.set_theme()

ax = sns.heatmap(cmc, annot=True,fmt=".0f", linewidths=.1, cmap="CMRmap")

# %%
# ATTENZIONE, con questo codice vengono cambiati i valori della matrice cmc
# viene fatto solo per plottare la matrice con le percentuali per ogni riga
# poi riaggiornare la matrice di confusione

cmc2 = cmc

for i in range(7):
  total = 0
  for j in range(7):
    total += cmc[i,j]
  for j in range(7):
    cmc2[i,j] = cmc[i,j]*100/total
  
plt.rcParams["figure.figsize"] = (8,6)
sns.set_theme()

ax = sns.heatmap(cmc2, annot=True,vmin=0.0, vmax=100.0,fmt=".0f", linewidths=.1, cmap="crest")
#ax = sns.heatmap(cmc, linewidths=.3)
#ax = sns.heatmap(cmc, cmap="YlGnBu")
