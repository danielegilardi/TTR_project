# %% [markdown]
# <a href="https://colab.research.google.com/github/danielegilardi/TTR_project/blob/main/KNN/Copy_of_TTR_progetto_KNN_PCA_100_scaled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Classificatore: KNN
#
# Features: estratte da immagini nwh con PCA (primi 100 autovalori) e normalizzate

# %%
# !wget https://www.dropbox.com/s/gq85jifxphmzfl8/features_PCA_100.zip?dl=0
# !unzip features_PCA_100.zip?dl=0

# !wget https://www.dropbox.com/s/rhbde9gw8vnk9dm/array_labels.zip?dl=0
# !unzip array_labels.zip?dl=0
# Out:
# --2022-05-23 21:18:36--  https://www.dropbox.com/s/gq85jifxphmzfl8/features_PCA_100.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/gq85jifxphmzfl8/features_PCA_100.zip [following]
# --2022-05-23 21:18:37--  https://www.dropbox.com/s/raw/gq85jifxphmzfl8/features_PCA_100.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc585322166ae9adf2030cbcd704.dl.dropboxusercontent.com/cd/0/inline/Bl0HiYnMNPcypv-OMGsFzlvhz3Dr0ppQPtkAqcIku5-AxVdcYJuQed02ld0miAA6Uya9NqOUMDAV_Lv4tqfxJH7lhAePCTuzo9rQNo5J9iM0701pt-fqpn-tlUll0CtwZcawqBAavdSxOmnxKbSYTz7TnPKQRWqtMbfvULs6rCD5og/file# [following]
# --2022-05-23 21:18:37--  https://uc585322166ae9adf2030cbcd704.dl.dropboxusercontent.com/cd/0/inline/Bl0HiYnMNPcypv-OMGsFzlvhz3Dr0ppQPtkAqcIku5-AxVdcYJuQed02ld0miAA6Uya9NqOUMDAV_Lv4tqfxJH7lhAePCTuzo9rQNo5J9iM0701pt-fqpn-tlUll0CtwZcawqBAavdSxOmnxKbSYTz7TnPKQRWqtMbfvULs6rCD5og/file
# Resolving uc585322166ae9adf2030cbcd704.dl.dropboxusercontent.com (uc585322166ae9adf2030cbcd704.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:6019:15::a27d:40f
# Connecting to uc585322166ae9adf2030cbcd704.dl.dropboxusercontent.com (uc585322166ae9adf2030cbcd704.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bl1cZuTRXhp8qjwX1DRduPnDM4QDRywCANhJp1DjS82T5-wrS3wlVvRYt3Ufwgq1k__PUnCPIF7xPCrjjWOoIYPDEC61lIom8cf979L3hmsfV-BB0hOCeQkcyAsJwqJf-MFjrtqbnuhrn5sRk0JQfXsmgPpwoWjaVrIY4t09wDKYQpGWfxCOKTog5G59ZxyKuGCX9lP2O4hCTazOIEmvjfMw1nM9DWk4txnJBgVLLNlCxnyiYob-bG_jRh2Gn2EGIEHVhZAQleYO71a7knP6I-8phtnuBFwLMbnKdQBn686DzbJooaYgY8JEYiyWVuVAeshQOqEzjTeTb3_vY0cuXpiG8x7YdSGMZpd0EQZ0oBxYHu2jTHZdxu_66cenHuwEHQBa6RpbgSpvkC0NGtdu9hLlcTbjsg6aLDLoCCGRklXz5w/file [following]
# --2022-05-23 21:18:37--  https://uc585322166ae9adf2030cbcd704.dl.dropboxusercontent.com/cd/0/inline2/Bl1cZuTRXhp8qjwX1DRduPnDM4QDRywCANhJp1DjS82T5-wrS3wlVvRYt3Ufwgq1k__PUnCPIF7xPCrjjWOoIYPDEC61lIom8cf979L3hmsfV-BB0hOCeQkcyAsJwqJf-MFjrtqbnuhrn5sRk0JQfXsmgPpwoWjaVrIY4t09wDKYQpGWfxCOKTog5G59ZxyKuGCX9lP2O4hCTazOIEmvjfMw1nM9DWk4txnJBgVLLNlCxnyiYob-bG_jRh2Gn2EGIEHVhZAQleYO71a7knP6I-8phtnuBFwLMbnKdQBn686DzbJooaYgY8JEYiyWVuVAeshQOqEzjTeTb3_vY0cuXpiG8x7YdSGMZpd0EQZ0oBxYHu2jTHZdxu_66cenHuwEHQBa6RpbgSpvkC0NGtdu9hLlcTbjsg6aLDLoCCGRklXz5w/file
# Reusing existing connection to uc585322166ae9adf2030cbcd704.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 29821409 (28M) [application/zip]
# Saving to: ‘features_PCA_100.zip?dl=0’
#
# features_PCA_100.zi 100%[===================>]  28.44M  85.4MB/s    in 0.3s
#
# 2022-05-23 21:18:38 (85.4 MB/s) - ‘features_PCA_100.zip?dl=0’ saved [29821409/29821409]
#
# Archive:  features_PCA_100.zip?dl=0
#    creating: features_PCA_100/
#   inflating: features_PCA_100/features_test_PCA_100.npy
#   inflating: features_PCA_100/features_train_PCA_100.npy
# --2022-05-23 21:18:38--  https://www.dropbox.com/s/rhbde9gw8vnk9dm/array_labels.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/rhbde9gw8vnk9dm/array_labels.zip [following]
# --2022-05-23 21:18:38--  https://www.dropbox.com/s/raw/rhbde9gw8vnk9dm/array_labels.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce3693eeb9b2ed714820e2aa17b.dl.dropboxusercontent.com/cd/0/inline/Bl2GwUzHX7a08lUxOsXpQovzvWXQWxDy9s2-zRNFOn0IESu1LDa4dJbapfbSDKRxzxGGH2lZO5uDVj60RDzm8UmwLoydwY5J_6-MW99pNFSsF-8UT9YtVX9Gmc9xUB9oHUYW4UbtH8ScSiATt1WpcqUFJ0oZJHo04OeoOW08QkXvoA/file# [following]
# --2022-05-23 21:18:39--  https://uce3693eeb9b2ed714820e2aa17b.dl.dropboxusercontent.com/cd/0/inline/Bl2GwUzHX7a08lUxOsXpQovzvWXQWxDy9s2-zRNFOn0IESu1LDa4dJbapfbSDKRxzxGGH2lZO5uDVj60RDzm8UmwLoydwY5J_6-MW99pNFSsF-8UT9YtVX9Gmc9xUB9oHUYW4UbtH8ScSiATt1WpcqUFJ0oZJHo04OeoOW08QkXvoA/file
# Resolving uce3693eeb9b2ed714820e2aa17b.dl.dropboxusercontent.com (uce3693eeb9b2ed714820e2aa17b.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:6019:15::a27d:40f
# Connecting to uce3693eeb9b2ed714820e2aa17b.dl.dropboxusercontent.com (uce3693eeb9b2ed714820e2aa17b.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bl1JnW8UGP2TA5h3qVgB6oCA8oPewxlcoVe63mxNqH3tUZI2aIcDheKLHa9YnYy0y5A0iGrF7oGc-6N2nXhGpLjoIu0aMy5Ti6M2h-aBDhPMKqbCweQkTBuKBi1CYqPUtpnAemNyzGurIudLPXC69VJfnicHHtRYgMOylv37MaEXd5VgqViswkiXuGSbSraMpO1RjlS3B2nY_uoQzDKLFeeTIKxwbm7bfQaeaGRZ1-IemazXoPgiH62flolTxQ6wtqxbZICybtFfScZx0mZLh4ZIYr9yQb9HlE3zsed499gAhnh8wRo0KuXTzOb371lrQ3DN5pxhYdBXAFfIWU_RPFtUAZHu9eqJO5pj07hC8suvOKmI9PF7PPH17pr5VzMEeVMYofCl7B-uT-t2fvJcsIrA27mlctyNKkyREn32WxuDLA/file [following]
# --2022-05-23 21:18:39--  https://uce3693eeb9b2ed714820e2aa17b.dl.dropboxusercontent.com/cd/0/inline2/Bl1JnW8UGP2TA5h3qVgB6oCA8oPewxlcoVe63mxNqH3tUZI2aIcDheKLHa9YnYy0y5A0iGrF7oGc-6N2nXhGpLjoIu0aMy5Ti6M2h-aBDhPMKqbCweQkTBuKBi1CYqPUtpnAemNyzGurIudLPXC69VJfnicHHtRYgMOylv37MaEXd5VgqViswkiXuGSbSraMpO1RjlS3B2nY_uoQzDKLFeeTIKxwbm7bfQaeaGRZ1-IemazXoPgiH62flolTxQ6wtqxbZICybtFfScZx0mZLh4ZIYr9yQb9HlE3zsed499gAhnh8wRo0KuXTzOb371lrQ3DN5pxhYdBXAFfIWU_RPFtUAZHu9eqJO5pj07hC8suvOKmI9PF7PPH17pr5VzMEeVMYofCl7B-uT-t2fvJcsIrA27mlctyNKkyREn32WxuDLA/file
# Reusing existing connection to uce3693eeb9b2ed714820e2aa17b.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1265 (1.2K) [application/zip]
# Saving to: ‘array_labels.zip?dl=0’
#
# array_labels.zip?dl 100%[===================>]   1.24K  --.-KB/s    in 0s
#
# 2022-05-23 21:18:39 (405 MB/s) - ‘array_labels.zip?dl=0’ saved [1265/1265]
#
# Archive:  array_labels.zip?dl=0
#    creating: array_labels/
#   inflating: array_labels/array_test_labels.npy
#   inflating: array_labels/array_train_labels.npy

# %%
import numpy as np

# Carico in memoria le features
x_train_t = np.load('features_PCA_100/features_train_PCA_100.npy')
y_train = np.load('array_labels/array_train_labels.npy')

x_test_t = np.load('features_PCA_100/features_test_PCA_100.npy')
y_test = np.load('array_labels/array_test_labels.npy')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train_t)
x_test = scaler.fit_transform(x_test_t)

# %%
# Analizzo i dati

# Capisco quanti oggetti e feature ho
nobj = x_train.shape[0]
nfeat = x_train.shape[1]
print(nobj, nfeat)

# Capisco come sono i dati: scatter plot
from matplotlib import pyplot as plt

plt.scatter(x_train[:,0],x_train[:,1], c=y_train)
plt.show()
# Out:
# 31805 100

# %%
# Inizializzo i parametri

K = 1
fun = 'euclidean'

# Calcolo la distanza fra tutti gli oggetti di train e gli oggetti di test


from scipy.spatial.distance import cdist

D = cdist(x_train,x_test,metric=fun)
 
# Per ogni dato di test (argomento axis=0), ordino le distanze dalla più piccola alla più grande e trovo gli indici di train dei più vicini
# Tengo solo i primi K

neighbors = np.argsort(D, axis=0)

k_neighbors = neighbors[:K, :]

# Controllo le etichette di questi K punti: devo trovare la più frequente:
#     - Ottengo le etichette dei punti vicini
#     - Trovo l'etichetta più frequente, Utilizzo la moda

neighbors_labels = y_train[k_neighbors]


from scipy import stats
prediction = stats.mode(neighbors_labels, axis=0)[0]
print(np.shape(prediction))
print(prediction[:20])


# Calcolo l'accuratezza
accuracy = np.sum(prediction == y_test) / len(y_test)
print('Accuratezza del classificatore: ' + "{0:.2f}".format(accuracy*100) + '%')
# Out:
# (1, 7178)
# [[0 0 2 ... 2 6 6]]
# Accuratezza del classificatore: 66.79%

# %%
length = prediction.shape[1]
print(length)
print(prediction[:20])

predicted = np.reshape(prediction, length)

print(np.shape(predicted))
print(predicted[:20])
# Out:
# 7178
# [[0 0 2 ... 2 6 6]]
# (7178,)
# [0 0 2 0 5 0 0 0 0 0 0 0 0 5 0 0 0 0 0 0]

# %%
# trovo la matrice di confusione

cmc = np.zeros((7,7))

for pr,y_te in zip(predicted,y_test):
  cmc[y_te,pr] += 1.0

# %%
# calcolo accuratezza, precision e recall media rispetto alle 7 classi

accuracy = np.sum(cmc.diagonal())/np.sum(cmc)

precision = []
recall = []
for i in range(7):
  precision.append(cmc[i,i]/ np.sum(cmc[:,i]))
  recall.append(cmc[i,i]/ np.sum(cmc[i,:]))

precision = np.asarray(precision)
recall  = np.asarray(recall)

print(np.shape(precision))
print(np.shape(recall))

precision_m = np.mean(precision)
recall_m = np.mean(recall)

print(np.shape(precision_m))
print(np.shape(recall_m))
print(precision_m)
print(recall_m)

print('Accuratezza del classificatore: ' + "{0:.2f}".format(accuracy*100) + '%')
print('Precisione media del classificatore: ' + "{0:.2f}".format(precision_m))
print('Recall media del classificatore: ' + "{0:.2f}".format(recall_m))
# Out:
# (7,)
# (7,)
# ()
# ()
# 0.6655093579360972
# 0.6940517375128732
# Accuratezza del classificatore: 66.79%
# Precisione media del classificatore: 0.67
# Recall media del classificatore: 0.69

# %%
# stampo la matrice di confusione

from matplotlib import pyplot as plt
import seaborn as sns; 


plt.rcParams["figure.figsize"] = (8,6)
sns.set_theme()

ax = sns.heatmap(cmc, annot=True,fmt=".0f", linewidths=.1, cmap="CMRmap")

# %%
# ATTENZIONE, con questo codice vengono cambiati i valori della matrice cmc
# viene fatto solo per plottare una matrice con le percentuali per ogni riga

cmc2 = cmc

for i in range(7):
  total = 0
  for j in range(7):
    total += cmc[i,j]
  for j in range(7):
    cmc2[i,j] = cmc[i,j]*100/total
  
plt.rcParams["figure.figsize"] = (8,6)
sns.set_theme()

ax = sns.heatmap(cmc2, annot=True,vmin=0.0, vmax=100.0,fmt=".0f", linewidths=.1, cmap="crest")
#ax = sns.heatmap(cmc, linewidths=.3)
#ax = sns.heatmap(cmc, cmap="YlGnBu")
