# %% [markdown]
# <a href="https://colab.research.google.com/github/danielegilardi/TTR_project/blob/main/Copy_of_TTR_progetto_KNN_PCA_100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.dropbox.com/s/gq85jifxphmzfl8/features_PCA_100.zip?dl=0
# !unzip features_PCA_100.zip?dl=0

# !wget https://www.dropbox.com/s/rhbde9gw8vnk9dm/array_labels.zip?dl=0
# !unzip array_labels.zip?dl=0
# Out:
# --2022-05-09 21:53:57--  https://www.dropbox.com/s/gq85jifxphmzfl8/features_PCA_100.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/gq85jifxphmzfl8/features_PCA_100.zip [following]
# --2022-05-09 21:53:57--  https://www.dropbox.com/s/raw/gq85jifxphmzfl8/features_PCA_100.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4bd656540fa6d0b6ffc861fbb3.dl.dropboxusercontent.com/cd/0/inline/Bk_IANkeBa3yttFYF9w4EMhNaR1_5oJ84lxSMtak0xJjKD0ysXQntu0tscFFeXsjXsvbPDaxwl6g7bObjfgSu9NTte_etVFU4mlKiViyvKk1IY0rc53_kJOCDh_vSqGNMkb9QTgmwWG_ecC7CZ_cXfq0omASxt6mmKX-OZfXBY9YeA/file# [following]
# --2022-05-09 21:53:58--  https://uc4bd656540fa6d0b6ffc861fbb3.dl.dropboxusercontent.com/cd/0/inline/Bk_IANkeBa3yttFYF9w4EMhNaR1_5oJ84lxSMtak0xJjKD0ysXQntu0tscFFeXsjXsvbPDaxwl6g7bObjfgSu9NTte_etVFU4mlKiViyvKk1IY0rc53_kJOCDh_vSqGNMkb9QTgmwWG_ecC7CZ_cXfq0omASxt6mmKX-OZfXBY9YeA/file
# Resolving uc4bd656540fa6d0b6ffc861fbb3.dl.dropboxusercontent.com (uc4bd656540fa6d0b6ffc861fbb3.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to uc4bd656540fa6d0b6ffc861fbb3.dl.dropboxusercontent.com (uc4bd656540fa6d0b6ffc861fbb3.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bk9ZrrzTW5kTZMJ9uaH8tCVQ3YrrFNzb1R7NsxRHU5qDzFE5PkVNYG2Ohg3LbfjuKzt0Md-ES3R2eIDJT9NmKbgG_GpE7STr6vVGdmlDEj5EcUn1eOLQMFWFJMhqG_qecvf4JKnJHKlcvnSTxZmTy_qxL5rHJARBRSRgflp8Sy76yuu-XZS6ZxpdzJW1Oq2xG-b1NaitffcE2pdnBHa4QEjUrJ07nL-VPuD7IUhISEz6i7C1qBG7UWjZYB4DTHe4m7J-ya5mrbSm6D4ebkkvi1-QbpSiJ6LEi-zzkIagHlUmkHkqVggKE8xRCyEsn_rfxH4c0cnYF-sObtXslYAGkwqbI-tZ05pi7RaVv15PFiYA066E0GMxitV-QuyyUZDopdhAwr_lqCPVI-kVlRBQOaPcFgDW7IG1zu8-AImxVvs2Yw/file [following]
# --2022-05-09 21:53:58--  https://uc4bd656540fa6d0b6ffc861fbb3.dl.dropboxusercontent.com/cd/0/inline2/Bk9ZrrzTW5kTZMJ9uaH8tCVQ3YrrFNzb1R7NsxRHU5qDzFE5PkVNYG2Ohg3LbfjuKzt0Md-ES3R2eIDJT9NmKbgG_GpE7STr6vVGdmlDEj5EcUn1eOLQMFWFJMhqG_qecvf4JKnJHKlcvnSTxZmTy_qxL5rHJARBRSRgflp8Sy76yuu-XZS6ZxpdzJW1Oq2xG-b1NaitffcE2pdnBHa4QEjUrJ07nL-VPuD7IUhISEz6i7C1qBG7UWjZYB4DTHe4m7J-ya5mrbSm6D4ebkkvi1-QbpSiJ6LEi-zzkIagHlUmkHkqVggKE8xRCyEsn_rfxH4c0cnYF-sObtXslYAGkwqbI-tZ05pi7RaVv15PFiYA066E0GMxitV-QuyyUZDopdhAwr_lqCPVI-kVlRBQOaPcFgDW7IG1zu8-AImxVvs2Yw/file
# Reusing existing connection to uc4bd656540fa6d0b6ffc861fbb3.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 29821409 (28M) [application/zip]
# Saving to: ‘features_PCA_100.zip?dl=0’
#
# features_PCA_100.zi 100%[===================>]  28.44M  93.2MB/s    in 0.3s
#
# 2022-05-09 21:53:58 (93.2 MB/s) - ‘features_PCA_100.zip?dl=0’ saved [29821409/29821409]
#
# Archive:  features_PCA_100.zip?dl=0
#    creating: features_PCA_100/
#   inflating: features_PCA_100/features_test_PCA_100.npy
#   inflating: features_PCA_100/features_train_PCA_100.npy
# --2022-05-09 21:53:59--  https://www.dropbox.com/s/rhbde9gw8vnk9dm/array_labels.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/rhbde9gw8vnk9dm/array_labels.zip [following]
# --2022-05-09 21:53:59--  https://www.dropbox.com/s/raw/rhbde9gw8vnk9dm/array_labels.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucdf1855bba9ad7e67480df1ad7f.dl.dropboxusercontent.com/cd/0/inline/Bk9phw0qn4jin9T4b5GrWWiiSusv5fmYyUmPCTXV-50OcGA1D4ta4YtEB-R3gATJJBpwjtLCrSmaMeVdGdDxhlyqDm402NcA062BE-UWBomuELWtpRJq7kS4INzyw00OXIsRMqNT7afnO-un7nK8SI3dtXy2vhI1VZJQPA08zzKUMw/file# [following]
# --2022-05-09 21:54:00--  https://ucdf1855bba9ad7e67480df1ad7f.dl.dropboxusercontent.com/cd/0/inline/Bk9phw0qn4jin9T4b5GrWWiiSusv5fmYyUmPCTXV-50OcGA1D4ta4YtEB-R3gATJJBpwjtLCrSmaMeVdGdDxhlyqDm402NcA062BE-UWBomuELWtpRJq7kS4INzyw00OXIsRMqNT7afnO-un7nK8SI3dtXy2vhI1VZJQPA08zzKUMw/file
# Resolving ucdf1855bba9ad7e67480df1ad7f.dl.dropboxusercontent.com (ucdf1855bba9ad7e67480df1ad7f.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to ucdf1855bba9ad7e67480df1ad7f.dl.dropboxusercontent.com (ucdf1855bba9ad7e67480df1ad7f.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bk-fsbGeUJOKjLJcoTktoJpRP0OG3XEeHBWvmGnOeA4yHVWvP2I1Egs_xAxU63BOxXUmZxqPRl8yFVeSKxZJ1RF3_4DkkIUxZQKEn4vZSDQy1P93KGCQ1JBETkkda_CJbg1XiKB4nhvyXQIQOmIov6YTri-sv4aOtQOAgdh-cyEl8F4C6tm2KJQJXOS5VJCju_0jV_GP2c3myvp2AciLzxjyjMxRKfJ1dOpgnohx4Ywp7f-s4YzCjC9AHozuDZ5EQIEOLuf0vusCmJtXml2InIXRTMlmWhIWFbs8k-BXv_X4yaCCxub0C3Ca66pfd3eFAZ6XoIXDk83D5d6hs12YQKvDfVrd_brFmzG-GK8M_z8DRFs6EBZzHPaQqyjNqoDn1VGIurLZ8WAS5dv-i01nHLm9LWvB8RF3ToVYQfWNAWLOLw/file [following]
# --2022-05-09 21:54:00--  https://ucdf1855bba9ad7e67480df1ad7f.dl.dropboxusercontent.com/cd/0/inline2/Bk-fsbGeUJOKjLJcoTktoJpRP0OG3XEeHBWvmGnOeA4yHVWvP2I1Egs_xAxU63BOxXUmZxqPRl8yFVeSKxZJ1RF3_4DkkIUxZQKEn4vZSDQy1P93KGCQ1JBETkkda_CJbg1XiKB4nhvyXQIQOmIov6YTri-sv4aOtQOAgdh-cyEl8F4C6tm2KJQJXOS5VJCju_0jV_GP2c3myvp2AciLzxjyjMxRKfJ1dOpgnohx4Ywp7f-s4YzCjC9AHozuDZ5EQIEOLuf0vusCmJtXml2InIXRTMlmWhIWFbs8k-BXv_X4yaCCxub0C3Ca66pfd3eFAZ6XoIXDk83D5d6hs12YQKvDfVrd_brFmzG-GK8M_z8DRFs6EBZzHPaQqyjNqoDn1VGIurLZ8WAS5dv-i01nHLm9LWvB8RF3ToVYQfWNAWLOLw/file
# Reusing existing connection to ucdf1855bba9ad7e67480df1ad7f.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1265 (1.2K) [application/zip]
# Saving to: ‘array_labels.zip?dl=0’
#
# array_labels.zip?dl 100%[===================>]   1.24K  --.-KB/s    in 0s
#
# 2022-05-09 21:54:00 (161 MB/s) - ‘array_labels.zip?dl=0’ saved [1265/1265]
#
# Archive:  array_labels.zip?dl=0
#    creating: array_labels/
#   inflating: array_labels/array_test_labels.npy
#   inflating: array_labels/array_train_labels.npy

# %%
import numpy as np

# 1. Carico in memoria il dataset
x_train = np.load('features_PCA_100/features_train_PCA_100.npy')
y_train = np.load('array_labels/array_train_labels.npy')

x_test = np.load('features_PCA_100/features_test_PCA_100.npy')
y_test = np.load('array_labels/array_test_labels.npy')

# %%
# 2. Analizzo i dati

# Capisco quanti oggetti e feature ho
nobj = x_train.shape[0]
nfeat = x_train.shape[1]
print(nobj, nfeat)

# Capisco come sono i dati: scatter plot
from matplotlib import pyplot as plt

plt.scatter(x_train[:,0],x_train[:,1], c=y_train)
plt.show()
# Out:
# 31805 100

# %%
# Inizializzo i parametri

K = 1
fun = 'euclidean'

# Calcolo la distanza fra tutti gli oggetti di train e gli oggetti di test


from scipy.spatial.distance import cdist

D = cdist(x_train,x_test,metric=fun)
 
# Per ogni dato di test (argomento axis=0), ordino le distanze dalla più piccola alla più grande e trovo gli indici di train dei più vicini
# Tengo solo i primi K

neighbors = np.argsort(D, axis=0)

k_neighbors = neighbors[:K, :]

# Controllo le etichette di questi K punti: devo trovare la più frequente:
#     - Ottengo le etichette dei punti vicini
#     - Trovo l'etichetta più frequente, Utilizzo la moda

neighbors_labels = y_train[k_neighbors]


from scipy import stats
prediction = stats.mode(neighbors_labels, axis=0)[0]
print(np.shape(prediction))
print(prediction[:20])


# Calcolo l'accuratezza
accuracy = np.sum(prediction == y_test) / len(y_test)
print('Accuratezza del classificatore: ' + "{0:.2f}".format(accuracy*100) + '%')
# Out:
# (1, 7178)
# [[0 0 1 ... 6 5 6]]
# Accuratezza del classificatore: 66.90%

# %%
length = prediction.shape[1]
print(length)
print(prediction[:20])

predicted = np.reshape(prediction, length)

print(np.shape(predicted))
print(predicted[:20])
# Out:
# 7178
# [[0 0 1 ... 6 5 6]]
# (7178,)
# [0 0 1 0 3 0 0 0 0 3 0 0 0 4 0 0 0 0 0 0]

# %%
cmc = np.zeros((7,7))

for pr,y_te in zip(predicted,y_test):
  cmc[y_te,pr] += 1.0

# %%
# calcolo accuratezza, precision e recall media rispetto alle 7 classi

accuracy = np.sum(cmc.diagonal())/np.sum(cmc)

precision = []
recall = []
for i in range(7):
  precision.append(cmc[i,i]/ np.sum(cmc[:,i]))
  recall.append(cmc[i,i]/ np.sum(cmc[i,:]))

precision = np.asarray(precision)
recall  = np.asarray(recall)

print(np.shape(precision))
print(np.shape(recall))

precision_m = np.mean(precision)
recall_m = np.mean(recall)

print(np.shape(precision_m))
print(np.shape(recall_m))
print(precision_m)
print(recall_m)

print('Accuratezza del classificatore: ' + "{0:.2f}".format(accuracy*100) + '%')
print('Precisione media del classificatore: ' + "{0:.2f}".format(precision_m))
print('Recall media del classificatore: ' + "{0:.2f}".format(recall_m))
# Out:
# (7,)
# (7,)
# ()
# ()
# 0.664110634261779
# 0.7009088144238423
# Accuratezza del classificatore: 66.90%
# Precisione media del classificatore: 0.66
# Recall media del classificatore: 0.70

# %%
from matplotlib import pyplot as plt
import seaborn as sns; 


plt.rcParams["figure.figsize"] = (8,6)
sns.set_theme()

ax = sns.heatmap(cmc, annot=True,fmt=".0f", linewidths=.1, cmap="CMRmap")

# %%
# ATTENZIONE, con questo codice vengono cambiati i valori della matrice cmc
# viene fatto solo per plottare con le percentuali

cmc2 = cmc

for i in range(7):
  total = 0
  for j in range(7):
    total += cmc[i,j]
  for j in range(7):
    cmc2[i,j] = cmc[i,j]*100/total
  
plt.rcParams["figure.figsize"] = (8,6)
sns.set_theme()

ax = sns.heatmap(cmc2, annot=True,vmin=0.0, vmax=100.0,fmt=".0f", linewidths=.1, cmap="crest")
#ax = sns.heatmap(cmc, linewidths=.3)
#ax = sns.heatmap(cmc, cmap="YlGnBu")

# %%
import numpy as np
cm = np.array([[2,1,0], [3,4,5], [6,7,8]])
true_pos = np.diag(cm)
false_pos = np.sum(cm, axis=0) - true_pos
false_neg = np.sum(cm, axis=1) - true_pos

precision = np.sum(true_pos / (true_pos + false_pos))
recall = np.sum(true_pos / (true_pos + false_neg))

print(true_pos)
print(false_pos)
print(false_neg)
print(precision)
print(recall)
# Out:
# [2 4 8]
# [9 8 5]
# [ 1  8 13]
# 1.1305361305361306
# 1.380952380952381
