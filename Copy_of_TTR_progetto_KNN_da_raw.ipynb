# %% [markdown]
# <a href="https://colab.research.google.com/github/danielegilardi/TTR_project/blob/main/Copy_of_TTR_progetto_KNN_da_raw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Classificatore: KNN
#
# Features: da immagini (n,w,h)  "appiattite" in n, w * h

# %%
# !wget https://www.dropbox.com/s/89qruuhdpfd5gh0/dati_raw_2d.zip?dl=0
# !unzip dati_raw_2d.zip?dl=0

# !wget https://www.dropbox.com/s/rhbde9gw8vnk9dm/array_labels.zip?dl=0
# !unzip array_labels.zip?dl=0
# Out:
# --2022-05-09 23:05:21--  https://www.dropbox.com/s/89qruuhdpfd5gh0/dati_raw_2d.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/89qruuhdpfd5gh0/dati_raw_2d.zip [following]
# --2022-05-09 23:05:22--  https://www.dropbox.com/s/raw/89qruuhdpfd5gh0/dati_raw_2d.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc362d92195b962ad70e3f0a32a2.dl.dropboxusercontent.com/cd/0/inline/Bk_a9pzngNkzY83UrXW9Q734mAPiKUHZvSN7LtwcWhAmBbctw5rDEGyUietbxXtS_lBr4HpTAvdELygcCnPx8d8QLY0OmUIQ6rgYG5O9YMsxDg2dlV8b7TvAbW6U9Jf_81zuOoocDDQ9Dby4PBtQzLUh5gadsWPAmOAo00YLOhY43w/file# [following]
# --2022-05-09 23:05:23--  https://uc362d92195b962ad70e3f0a32a2.dl.dropboxusercontent.com/cd/0/inline/Bk_a9pzngNkzY83UrXW9Q734mAPiKUHZvSN7LtwcWhAmBbctw5rDEGyUietbxXtS_lBr4HpTAvdELygcCnPx8d8QLY0OmUIQ6rgYG5O9YMsxDg2dlV8b7TvAbW6U9Jf_81zuOoocDDQ9Dby4PBtQzLUh5gadsWPAmOAo00YLOhY43w/file
# Resolving uc362d92195b962ad70e3f0a32a2.dl.dropboxusercontent.com (uc362d92195b962ad70e3f0a32a2.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6017:15::a27d:20f
# Connecting to uc362d92195b962ad70e3f0a32a2.dl.dropboxusercontent.com (uc362d92195b962ad70e3f0a32a2.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bk9I9ifh-LqjBiQlbxlROSK09OsBFretIu23y5Y-PpRGJQad2YU_tUnAHJY5W3rz7jAYXC2NrZ5wRFtiVB6CsxmCws7JcYAUYYGOZSbqEV7dlIg_dHTe413rOsNsUy9xJM_5mFL8TLGMtu70YskAQCTqe6JnUcp9SThyh8x5XnjOX7IU6ZSbNbGRbzCNSoDc3wqgiZBWpJe_8UuK3wYJ7K6DLJ-JqlXqwnBU2KmoPy2qxBCMu2DWTxPI_GGhh4fzk9aEvNswh-youHGCl9wWv23SV6jZG1iAasNOCxX_iPSLwrX9p-TDu8yK8tyLz3FjFoQxiSHlbQfrZyqC-Pu2PYu-xv1X8o2LKMH0uG23-CnHxeUbzKvtxLW5_YenmWVyngiQGrgApLInJBk-y3Ap6E1i-sVMZmZ-0YbxeHqTNwyNyg/file [following]
15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bk-cH0enAQg4X15KGGVfV3EBlmcoCX9N78can8USjNwx9CfDOTJPt6uBQmvHiQSTvClc4FMmPPaWFSm5TZWEwH7h1dlCzeye6qntdwVpBmIrJUBy72H9I1bsRZFoTWE5HFd8PGCeJpzwN36MGx-05JD3zDCYpwQxrQ8eTUQlF_GowAExUNNEcc2ew8JNh54M0XMgVQXC4qjQFpm-0TinvqXZIwQBNyFzhWWjxEojlbb4ZZK-iR-0fg4SjIXXat4f8Or_V1yyJJYKWW0kjkmVWri0RVuCg7Lt-nZJRr5yrv_pNy-Zswd7vEw4-6RdID8zxuXSq6eopXs9HcgiKrnnhmn-KX46upazGw3M6Sen11kq8RzcB4TEUJd99N_JgtkwIpFc4yoXc-kgvF5n4_d7JJ_EB10WQiAbqnfAOszqjZ9OMw/file [following]
# --2022-05-09 23:05:36--  https://uce7cdec6595b4fdf33d216b0964.dl.dropboxusercontent.com/cd/0/inline2/Bk-cH0enAQg4X15KGGVfV3EBlmcoCX9N78can8USjNwx9CfDOTJPt6uBQmvHiQSTvClc4FMmPPaWFSm5TZWEwH7h1dlCzeye6qntdwVpBmIrJUBy72H9I1bsRZFoTWE5HFd8PGCeJpzwN36MGx-05JD3zDCYpwQxrQ8eTUQlF_GowAExUNNEcc2ew8JNh54M0XMgVQXC4qjQFpm-0TinvqXZIwQBNyFzhWWjxEojlbb4ZZK-iR-0fg4SjIXXat4f8Or_V1yyJJYKWW0kjkmVWri0RVuCg7Lt-nZJRr5yrv_pNy-Zswd7vEw4-6RdID8zxuXSq6eopXs9HcgiKrnnhmn-KX46upazGw3M6Sen11kq8RzcB4TEUJd99N_JgtkwIpFc4yoXc-kgvF5n4_d7JJ_EB10WQiAbqnfAOszqjZ9OMw/file
# Reusing existing connection to uce7cdec6595b4fdf33d216b0964.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1265 (1.2K) [application/zip]
# Saving to: ‘array_labels.zip?dl=0’
#
# array_labels.zip?dl 100%[===================>]   1.24K  --.-KB/s    in 0s
#
# 2022-05-09 23:05:36 (136 MB/s) - ‘array_labels.zip?dl=0’ saved [1265/1265]
#
# Archive:  array_labels.zip?dl=0
#    creating: array_labels/
#   inflating: array_labels/array_test_labels.npy
#   inflating: array_labels/array_train_labels.npy

# %%
import numpy as np

# Carico in memoria il dataset
x_train = np.load('dati_raw_2d/dati_raw_train_2d.npy')
y_train = np.load('array_labels/array_train_labels.npy')

x_test = np.load('dati_raw_2d/dati_raw_test_2d.npy')
y_test = np.load('array_labels/array_test_labels.npy')

# %%
# Analizzo i dati

# Capisco quanti oggetti e feature ho
nobj = x_train.shape[0]
nfeat = x_train.shape[1]
print(nobj, nfeat)

# Capisco come sono i dati: scatter plot
from matplotlib import pyplot as plt

plt.scatter(x_train[:,0],x_train[:,1], c=y_train)
plt.show()
# Out:
# 31805 2304

# %%
# Inizializzo i parametri

K = 1
fun = 'cosine'

# Calcolo la distanza fra tutti gli oggetti di train e gli oggetti di test

from scipy.spatial.distance import cdist

D = cdist(x_train,x_test,metric=fun)
 
# Per ogni dato di test (argomento axis=0), ordino le distanze dalla più piccola alla più grande e trovo gli indici di train dei più vicini
# Tengo solo i primi K

neighbors = np.argsort(D, axis=0)

k_neighbors = neighbors[:K, :]

# Controllo le etichette di questi K punti: devo trovare la più frequente:
#     - Ottengo le etichette dei punti vicini
#     - Trovo l'etichetta più frequente, Utilizzo la moda

neighbors_labels = y_train[k_neighbors]

from scipy import stats
prediction = stats.mode(neighbors_labels, axis=0)[0]
print(np.shape(prediction))
print(prediction[:20])

# Calcolo l'accuratezza
accuracy = np.sum(prediction == y_test) / len(y_test)
print('Accuratezza del classificatore: ' + "{0:.2f}".format(accuracy*100) + '%')
# Out:
# (1, 7178)
# [[0 0 0 ... 2 2 6]]
# Accuratezza del classificatore: 65.87%

# %%
length = prediction.shape[1]
print(length)
print(prediction[:20])

predicted = np.reshape(prediction, length)

print(np.shape(predicted))
print(predicted[:20])
# Out:
# 7178
# [[0 0 0 ... 2 2 6]]
# (7178,)
# [0 0 0 0 3 0 0 0 0 3 0 0 0 4 0 0 0 0 0 0]

# %%
# matrice di confusione

cmc = np.zeros((7,7))

for pr,y_te in zip(predicted,y_test):
  cmc[y_te,pr] += 1.0

# %%
# calcolo accuratezza, precision e recall media rispetto alle 7 classi

accuracy = np.sum(cmc.diagonal())/np.sum(cmc)

precision = []
recall = []
for i in range(7):
  precision.append(cmc[i,i]/ np.sum(cmc[:,i]))
  recall.append(cmc[i,i]/ np.sum(cmc[i,:]))

precision = np.asarray(precision)
recall  = np.asarray(recall)

print(np.shape(precision))
print(np.shape(recall))

precision_m = np.mean(precision)
recall_m = np.mean(recall)

print(np.shape(precision_m))
print(np.shape(recall_m))
print(precision_m)
print(recall_m)

print('Accuratezza del classificatore: ' + "{0:.2f}".format(accuracy*100) + '%')
print('Precisione media del classificatore: ' + "{0:.2f}".format(precision_m))
print('Recall media del classificatore: ' + "{0:.2f}".format(recall_m))
# Out:
# (7,)
# (7,)
# ()
# ()
# 0.6626595810865537
# 0.6892467774800747
# Accuratezza del classificatore: 65.87%
# Precisione media del classificatore: 0.66
# Recall media del classificatore: 0.69

# %%
# stampo la matrice di confusione

from matplotlib import pyplot as plt
import seaborn as sns; 


plt.rcParams["figure.figsize"] = (8,6)
sns.set_theme()

ax = sns.heatmap(cmc, annot=True,fmt=".0f", linewidths=.1, cmap="crest")

# %%
# ATTENZIONE, con questo codice vengono cambiati i valori della matrice cmc
# viene fatto solo per plottare una matrice con le percentuali per ogni riga

cmc2 = cmc

for i in range(7):
  total = 0
  for j in range(7):
    total += cmc[i,j]
  for j in range(7):
    cmc2[i,j] = cmc[i,j]*100/total
  
plt.rcParams["figure.figsize"] = (8,6)
sns.set_theme()

ax = sns.heatmap(cmc2, annot=True,vmin=0.0, vmax=100.0,fmt=".0f", linewidths=.1, cmap="CMRmap")
#ax = sns.heatmap(cmc, linewidths=.3)
#ax = sns.heatmap(cmc, cmap="YlGnBu")
